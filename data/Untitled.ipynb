# %%
import pandas as pd

# %%
pd.read_csv(r'train.csv',sep='\t',index_col=0)
# Out:
#                      text1                                text2  label
# 0                怎么看花呗怎么花的                        花呗分期怎么查分的那些商品      0
# 1         我在超市支付宝付款也是用的花呗吗                      在超市可以使用花呗额数大的商品      0
# 2      我刚刚用花呗支付，为什么商家没有收到款  刚才点外卖花呗付款***元优惠***元 实付***元 商家说没有收到款      1
# 3         我的蚂蚁借呗分期还款，每月怎么还                            借呗可以的分期还嘛      0
# 4                  我的花呗还了吗                               花呗可以替还      0
# ...                    ...                                  ...    ...
# 81976           花呗帐户被冻结怎么办                       我的花呗冻结，要怎么才能解冻      1
# 81977        取消订单，钱会退到花呗里吗                         花呗付款了可以取消退款吗      0
# 81978              花呗超额支付了                         要支付宝支付，不通过花呗      0
# 81979         为什么有些花呗不支持付款                        花呗付款电费需要什么时候还      0
# 81980           借呗关必可分期还款吗                           蚂蚁借呗可以分期烦吗      0
#
# [81981 rows x 3 columns]
